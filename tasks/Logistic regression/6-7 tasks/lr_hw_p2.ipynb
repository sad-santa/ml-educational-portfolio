# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import (accuracy_score,
                             f1_score,
                             recall_score,
                             precision_score)
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %% [markdown]
# # Task 6 #
#
# Имеется датасет для чаевых для таксиста . Но мы возьмём немного измененную версию данных. Скачать датасет.
#
# Сделайте разбиение на обучение и тест с соотношением 80/20 и random_state=10.
#
# Целевой признак tip_class.
#
# Обучите логистическую регрессию из sklearn с параметром max_iter=400 для решения поставленной задачи.
#
# Изучите масштаб в данных и если это требуется примените StandardScaler.
#
# Укажите метрики accuracy на тренировочной и тестовой выборках, округлив их до второго знака после точки.

# %%
data = pd.read_csv('./taxi.csv', delimiter = ',')
data.head()
# Out:
#    trip_duration  distance_traveled  num_of_passengers    fare  \
# 0          748.0               2.75                1.0   75.00
# 1         1187.0               3.43                1.0  105.00
# 2          329.0               2.09                1.0   45.00
# 3          355.0               1.74                1.0   45.00
# 4         1288.0               5.21                1.0  116.25
#
#    miscellaneous_fees  total_fare  surge_applied  tip_class
# 0               6.300     105.300              0   over med
# 1              13.200     142.200              0   over med
# 2              13.200      70.200              0  under med
# 3              26.625      71.625              1        low
# 4              26.325     178.575              1       high

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137165 entries, 0 to 137164
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   trip_duration       137165 non-null  float64
#  1   distance_traveled   137165 non-null  float64
#  2   num_of_passengers   137165 non-null  float64
#  3   fare                137165 non-null  float64
#  4   miscellaneous_fees  137165 non-null  float64
#  5   total_fare          137165 non-null  float64
#  6   surge_applied       137165 non-null  int64
#  7   tip_class           137165 non-null  object
# dtypes: float64(6), int64(1), object(1)
# memory usage: 8.4+ MB

# %%
data.describe()
# Out:
#        trip_duration  distance_traveled  num_of_passengers           fare  \
# count  137165.000000      137165.000000      137165.000000  137165.000000
# mean     1166.376743           5.380609           1.288040     101.619808
# std      4620.940573         154.736891           0.923911      79.099130
# min         0.000000           0.020000           0.000000       0.000000
# 25%       480.000000           2.120000           1.000000      56.250000
# 50%       737.000000           3.410000           1.000000      78.750000
# 75%      1121.000000           5.950000           1.000000     120.000000
# max     86384.000000       57283.910000           9.000000    3963.750000
#
#        miscellaneous_fees     total_fare  surge_applied
# count       137165.000000  137165.000000  137165.000000
# mean            16.695971     137.698063       0.341202
# std             13.121517      97.010507       0.474115
# min             -0.500000       0.000000       0.000000
# 25%              6.000000      79.200000       0.000000
# 50%             13.100000     112.875000       0.000000
# 75%             26.625000     163.500000       1.000000
# max            435.000000    3969.750000       1.000000

# %%
data.describe(include='object')
# Out:
#         tip_class
# count      137165
# unique          4
# top     under med
# freq        35798

# %%
X = data.drop(['tip_class'], axis=1).values
y = data['tip_class']
X
# Out:
# array([[7.4800e+02, 2.7500e+00, 1.0000e+00, ..., 6.3000e+00, 1.0530e+02,
#         0.0000e+00],
#        [1.1870e+03, 3.4300e+00, 1.0000e+00, ..., 1.3200e+01, 1.4220e+02,
#         0.0000e+00],
#        [3.2900e+02, 2.0900e+00, 1.0000e+00, ..., 1.3200e+01, 7.0200e+01,
#         0.0000e+00],
#        ...,
#        [4.3800e+02, 1.2900e+00, 1.0000e+00, ..., 3.4575e+01, 9.5325e+01,
#         1.0000e+00],
#        [5.7100e+02, 2.8200e+00, 1.0000e+00, ..., 6.0000e+00, 6.9750e+01,
#         0.0000e+00],
#        [4.9100e+02, 2.1600e+00, 1.0000e+00, ..., 1.3500e+01, 6.9750e+01,
#         0.0000e+00]])

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, shuffle=True, random_state=10)

# %%
pipe = Pipeline([
    ('scaller', StandardScaler()),
    ('LR', LogisticRegression(max_iter=400))
])

pipe.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('scaller', StandardScaler()),
#                 ('LR', LogisticRegression(max_iter=400))])

# %% [markdown]
# Answer 6:

# %%
acc_train = accuracy_score(y_train, pipe.predict(x_train))
print(f'acc_train={acc_train}')
# Out:
# acc_train=0.9594937447143566

# %%
acc_test = accuracy_score(y_test, pipe.predict(x_test))
print(f'acc_test={acc_test}')
# Out:
# acc_test=0.9592033127260002

# %% [markdown]
# # Task 7 #
#
# Продолжайте работать с датасетом предыдущего задания.
#
# Посчитайте, сколько получилось ошибочных предсказаний в процентном соотношении по каждому классу на тестовой выборке и укажите в ответе, округлив проценты до второго знака после точки.

# %%
y_pred = pipe.predict(x_test)
y_pred
# Out:
# array(['low', 'low', 'under med', ..., 'under med', 'high', 'high'],
#       dtype=object)

# %%
y_test_ser = pd.Series(y_test).reset_index(drop=True)
y_pred_ser = pd.Series(y_pred).reset_index(drop=True)
y_pred_ser
# Out:
# 0              low
# 1              low
# 2        under med
# 3              low
# 4        under med
#            ...
# 34287    under med
# 34288         high
# 34289    under med
# 34290         high
# 34291         high
# Length: 34292, dtype: object

# %%
errors = y_test_ser != y_pred_ser

# %% [markdown]
# Answer 7:

# %%
for cls in sorted(y_test_ser.unique()):
    total = sum(y_test_ser == cls)
    incorrect = sum((y_test_ser == cls) & errors)
    percent = round(incorrect/total*100, 2)
    print(f'persent of error class {cls} = {percent:.2f}')
# Out:
# persent of error class high = 2.50
# persent of error class low = 7.17
# persent of error class over med = 6.86
# persent of error class under med = 0.03
